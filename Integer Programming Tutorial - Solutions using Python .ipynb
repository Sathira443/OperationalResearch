# %%
pip install pulp
# Out:
# Collecting pulp
#   Downloading PuLP-2.8.0-py3-none-any.whl.metadata (5.4 kB)
# Downloading PuLP-2.8.0-py3-none-any.whl (17.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.7/17.7 MB 2.2 MB/s eta 0:00:0000:0100:01
# Installing collected packages: pulp
# Successfully installed pulp-2.8.0
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Q1

# %%
from pulp import LpMinimize, LpProblem, LpVariable, LpInteger

# Create a linear programming problem
prob = LpProblem(name="Mnimize_Cost", sense=LpMinimize)

# Define decision variables
y1 = LpVariable(name="y1", cat="Binary")
y2 = LpVariable(name="y2", cat="Binary")
y3 = LpVariable(name="y3", cat="Binary")

x1 = LpVariable(name=f"x1", lowBound=0, cat=LpInteger)
x2 = LpVariable(name=f"x2", lowBound=0, cat=LpInteger)
x3 = LpVariable(name=f"x3", lowBound=0, cat=LpInteger)

# Define the objective function
prob += 1600 * y1 + 2500 * y2 + 1800 * y3 + 2.5 * x1 + 2.1 * x2 + 2.2 * x3, "Profit"

# Add constraints
prob += x1 + x2 + x3 >= 500, "Constraint1"
prob += x1 <= 400 * y1, "Constraint2"
prob += x2 <= 400 * y2, "Constraint3"
prob += x3 <= 400 * y3, "Constraint4"

# Solve the problem
prob.solve()

# Print the results
print("Status:", prob.status)
print("Objective Value (Profit):", round(prob.objective.value(), 3))

# Print the values of decision variables
for var in prob.variables():
    print(f"{var.name} = {var.value()}")
# Out:
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/sathira/anaconda3/envs/bio/lib/python3.9/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/3440e90f312c4c3aa7aaef87095f49ba-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /tmp/3440e90f312c4c3aa7aaef87095f49ba-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 37 RHS
# At line 42 BOUNDS
# At line 49 ENDATA
# Problem MODEL has 4 rows, 6 columns and 9 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 3270 - 0.00 seconds
# Cgl0004I processed model has 4 rows, 6 columns (6 integer (3 of which binary)) and 9 elements
# Cutoff increment increased from 1e-05 to 0.0999
# Cbc0038I Initial state - 1 integers unsatisfied sum - 0.25
# Cbc0038I Pass   1: suminf.    0.25000 (1) obj. 3270 iterations 0
# Cbc0038I Solution found of 4620
# Cbc0038I Cleaned solution of 4620
# Cbc0038I Before mini branch and bound, 5 integers at bound fixed and 0 continuous of which 1 were internal integer and 0 internal continuous
# Cbc0038I Full problem 4 rows 6 columns, reduced to 0 rows 0 columns
# Cbc0038I Mini branch and bound did not improve solution (0.01 seconds)
# Cbc0038I Round again with cutoff of 4484.9
# Cbc0038I Pass   2: suminf.    0.25000 (1) obj. 3270 iterations 0
# Cbc0038I Pass   3: suminf.    0.55065 (3) obj. 4484.9 iterations 2
# Cbc0038I Pass   4: suminf.    0.55065 (3) obj. 4484.9 iterations 0
# Cbc0038I Pass   5: suminf.    0.55065 (3) obj. 4484.9 iterations 0
# Cbc0038I Pass   6: suminf.    0.55065 (3) obj. 4484.9 iterations 0
# Cbc0038I Pass   7: suminf.    0.25000 (1) obj. 3330 iterations 3
# Cbc0038I Pass   8: suminf.    0.25000 (1) obj. 3330 iterations 0
# Cbc0038I Pass   9: suminf.    0.25000 (1) obj. 3330 iterations 0
# Cbc0038I Pass  10: suminf.    0.25000 (1) obj. 3330 iterations 0
# Cbc0038I Pass  11: suminf.    0.94110 (3) obj. 4484.9 iterations 3
# Cbc0038I Pass  12: suminf.    0.25000 (1) obj. 3330 iterations 2
# Cbc0038I Pass  13: suminf.    0.25000 (1) obj. 3330 iterations 0
# Cbc0038I Pass  14: suminf.    0.94110 (3) obj. 4484.9 iterations 3
# Cbc0038I Pass  15: suminf.    0.25000 (1) obj. 3330 iterations 2
# Cbc0038I Pass  16: suminf.    0.25000 (1) obj. 3270 iterations 2
# Cbc0038I Pass  17: suminf.    0.25000 (1) obj. 3270 iterations 1
# Cbc0038I Pass  18: suminf.    0.25000 (1) obj. 3270 iterations 0
# Cbc0038I Pass  19: suminf.    0.25000 (1) obj. 3270 iterations 0
# Cbc0038I Pass  20: suminf.    0.25000 (1) obj. 3270 iterations 1
# Cbc0038I Pass  21: suminf.    0.25000 (1) obj. 3270 iterations 1
# Cbc0038I Pass  22: suminf.    0.55065 (3) obj. 4484.9 iterations 2
# Cbc0038I Pass  23: suminf.    0.55065 (3) obj. 4484.9 iterations 0
# Cbc0038I Pass  24: suminf.    0.94110 (3) obj. 4484.9 iterations 5
# Cbc0038I Pass  25: suminf.    0.94110 (3) obj. 4484.9 iterations 0
# Cbc0038I Pass  26: suminf.    0.94110 (3) obj. 4484.9 iterations 0
# Cbc0038I Pass  27: suminf.    0.94110 (3) obj. 4484.9 iterations 0
# Cbc0038I Pass  28: suminf.    0.94110 (3) obj. 4484.9 iterations 0
# Cbc0038I Pass  29: suminf.    0.94110 (3) obj. 4484.9 iterations 0
# Cbc0038I Pass  30: suminf.    0.94110 (3) obj. 4484.9 iterations 0
# Cbc0038I Pass  31: suminf.    0.55065 (3) obj. 4484.9 iterations 4
# Cbc0038I Rounding solution of 4530 is better than previous of 4620
#
# Cbc0038I Before mini branch and bound, 0 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 4 rows 6 columns, reduced to 4 rows 6 columns
# Cbc0038I Mini branch and bound did not improve solution (0.01 seconds)
# Cbc0038I Round again with cutoff of 4241.9
# Cbc0038I Pass  31: suminf.    0.25000 (1) obj. 3270 iterations 0
# Cbc0038I Pass  32: suminf.    0.98101 (3) obj. 4241.9 iterations 2
# Cbc0038I Pass  33: suminf.    0.98101 (3) obj. 4241.9 iterations 0
# Cbc0038I Pass  34: suminf.    0.84476 (3) obj. 4241.9 iterations 5
# Cbc0038I Pass  35: suminf.    0.25000 (1) obj. 3330 iterations 2
# Cbc0038I Pass  36: suminf.    0.25000 (1) obj. 3270 iterations 2
# Cbc0038I Pass  37: suminf.    0.98101 (3) obj. 4241.9 iterations 3
# Cbc0038I Pass  38: suminf.    0.25000 (1) obj. 3330 iterations 3
# Cbc0038I Pass  39: suminf.    0.25000 (1) obj. 3990 iterations 4
# Cbc0038I Pass  40: suminf.    0.54192 (3) obj. 4241.9 iterations 2
# Cbc0038I Pass  41: suminf.    0.54192 (3) obj. 4241.9 iterations 0
# Cbc0038I Pass  42: suminf.    0.25000 (1) obj. 3990 iterations 2
# Cbc0038I Pass  43: suminf.    0.54192 (3) obj. 4241.9 iterations 2
# Cbc0038I Pass  44: suminf.    0.25000 (1) obj. 3270 iterations 2
# Cbc0038I Pass  45: suminf.    0.98101 (3) obj. 4241.9 iterations 2
# Cbc0038I Pass  46: suminf.    0.98101 (3) obj. 4241.9 iterations 0
# Cbc0038I Pass  47: suminf.    0.98101 (3) obj. 4241.9 iterations 0
# Cbc0038I Pass  48: suminf.    0.98101 (3) obj. 4241.9 iterations 0
# Cbc0038I Pass  49: suminf.    0.98101 (3) obj. 4241.9 iterations 0
# Cbc0038I Pass  50: suminf.    0.98101 (3) obj. 4241.9 iterations 0
# Cbc0038I Pass  51: suminf.    0.25000 (1) obj. 3330 iterations 3
# Cbc0038I Pass  52: suminf.    0.25000 (1) obj. 3330 iterations 0
# Cbc0038I Pass  53: suminf.    0.84476 (3) obj. 4241.9 iterations 3
# Cbc0038I Pass  54: suminf.    0.25000 (1) obj. 3330 iterations 2
# Cbc0038I Pass  55: suminf.    0.25000 (1) obj. 3330 iterations 0
# Cbc0038I Pass  56: suminf.    0.25000 (1) obj. 3330 iterations 0
# Cbc0038I Pass  57: suminf.    0.25000 (1) obj. 3330 iterations 0
# Cbc0038I Pass  58: suminf.    0.25000 (1) obj. 3270 iterations 2
# Cbc0038I Pass  59: suminf.    0.98101 (3) obj. 4241.9 iterations 3
# Cbc0038I Pass  60: suminf.    0.98101 (3) obj. 4241.9 iterations 0
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 0 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 4 rows 6 columns, reduced to 4 rows 6 columns
# Cbc0038I Mini branch and bound did not improve solution (0.01 seconds)
# Cbc0038I After 0.01 seconds - Feasibility pump exiting with objective of 4530 - took 0.00 seconds
# Cbc0012I Integer solution of 4530 found by feasibility pump after 0 iterations and 0 nodes (0.01 seconds)
# Cbc0006I The LP relaxation is infeasible or too expensive
# Cbc0013I At root node, 0 cuts changed objective from 3270 to 4530.3 in 1 passes
# Cbc0014I Cut generator 0 (Probing) - 4 row cuts average 2.5 elements, 3 column cuts (3 active)  in 0.000 seconds - new frequency is 1
# Cbc0014I Cut generator 1 (Gomory) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 7 (ZeroHalf) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0001I Search completed - best objective 4530, took 0 iterations and 0 nodes (0.01 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Cuts at root node changed objective from 3270 to 4530.3
# Probing was tried 1 times and created 7 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                4530.00000000
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.01
# Time (Wallclock seconds):       0.01
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.01
#
# Status: 1
# Objective Value (Profit): 4530.0
# x1 = 100.0
# x2 = 0.0
# x3 = 400.0
# y1 = 1.0
# y2 = 0.0
# y3 = 1.0

# %% [markdown]
# # Q2

# %%
from pulp import LpMinimize, LpProblem, LpVariable, LpInteger

# Create a linear programming problem
prob = LpProblem(name="Mnimize_Cost", sense=LpMinimize)

# Define decision variables
y1 = LpVariable(name="y1", cat="Binary")
y2 = LpVariable(name="y2", cat="Binary")
y3 = LpVariable(name="y3", cat="Binary")

x1 = LpVariable(name=f"x1", lowBound=0, cat=LpInteger)
x2 = LpVariable(name=f"x2", lowBound=0, cat=LpInteger)
x3 = LpVariable(name=f"x3", lowBound=0, cat=LpInteger)

# Define the objective function
prob += 150 * y1 + 240 * y2 + 300 * y3 + 15 * x1 + 10 * x2 + 8 * x3, "Profit"

# Add constraints
prob += x1 + x2 + x3 >= 4200, "Constraint1"
prob += x1 <= 2000 * y1, "Constraint2"
prob += x2 <= 3000 * y2, "Constraint3"
prob += x3 <= 3500 * y3, "Constraint4"

# Solve the problem
prob.solve()

# Print the results
print("Status:", prob.status)
print("Objective Value (Profit):", round(prob.objective.value(), 3))

# Print the values of decision variables
for var in prob.variables():
    print(f"{var.name} = {var.value()}")
# Out:
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/sathira/anaconda3/envs/bio/lib/python3.9/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/96818dbdbe9842e7b1364f4dd7b26226-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /tmp/96818dbdbe9842e7b1364f4dd7b26226-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 37 RHS
# At line 42 BOUNDS
# At line 49 ENDATA
# Problem MODEL has 4 rows, 6 columns and 9 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 35356 - 0.00 seconds
# Cgl0004I processed model has 4 rows, 6 columns (6 integer (3 of which binary)) and 9 elements
# Cutoff increment increased from 1e-05 to 0.9999
# Cbc0038I Initial state - 1 integers unsatisfied sum - 0.233333
# Cbc0038I Pass   1: suminf.    0.23333 (1) obj. 35356 iterations 0
# Cbc0038I Solution found of 35540
# Cbc0038I Cleaned solution of 35540
# Cbc0038I Before mini branch and bound, 5 integers at bound fixed and 0 continuous of which 1 were internal integer and 0 internal continuous
# Cbc0038I Full problem 4 rows 6 columns, reduced to 0 rows 0 columns
# Cbc0038I Mini branch and bound did not improve solution (0.00 seconds)
# Cbc0038I Round again with cutoff of 35520.7
# Cbc0038I Reduced cost fixing fixed 1 variables on major pass 2
# Cbc0038I Pass   2: suminf.    0.23333 (1) obj. 35356 iterations 0
# Cbc0038I Pass   3: suminf.    0.08042 (1) obj. 35520.7 iterations 1
# Cbc0038I Pass   4: suminf.    0.08042 (1) obj. 35520.7 iterations 0
# Cbc0038I Pass   5: suminf.    0.08042 (1) obj. 35520.7 iterations 0
# Cbc0038I Pass   6: suminf.    0.08042 (1) obj. 35520.7 iterations 0
# Cbc0038I Pass   7: suminf.    0.08042 (1) obj. 35520.7 iterations 0
# Cbc0038I Pass   8: suminf.    0.29458 (1) obj. 35520.7 iterations 1
# Cbc0038I Pass   9: suminf.    0.25669 (3) obj. 35520.7 iterations 1
# Cbc0038I Pass  10: suminf.    0.29458 (1) obj. 35520.7 iterations 1
# Cbc0038I Pass  11: suminf.    0.29458 (1) obj. 35520.7 iterations 0
# Cbc0038I Pass  12: suminf.    0.08042 (1) obj. 35520.7 iterations 1
# Cbc0038I Pass  13: suminf.    0.29458 (1) obj. 35520.7 iterations 1
# Cbc0038I Pass  14: suminf.    0.29458 (1) obj. 35520.7 iterations 0
# Cbc0038I Pass  15: suminf.    0.25669 (3) obj. 35520.7 iterations 1
# Cbc0038I Pass  16: suminf.    0.29458 (1) obj. 35520.7 iterations 1
# Cbc0038I Pass  17: suminf.    0.29458 (1) obj. 35520.7 iterations 0
# Cbc0038I Pass  18: suminf.    0.25669 (3) obj. 35520.7 iterations 1
# Cbc0038I Pass  19: suminf.    0.25669 (3) obj. 35520.7 iterations 0
# Cbc0038I Pass  20: suminf.    0.23333 (1) obj. 35356 iterations 2
# Cbc0038I Pass  21: suminf.    0.23333 (1) obj. 35356 iterations 0
# Cbc0038I Pass  22: suminf.    0.25669 (3) obj. 35520.7 iterations 2
# Cbc0038I Pass  23: suminf.    0.23333 (1) obj. 35356 iterations 2
# Cbc0038I Pass  24: suminf.    0.25669 (3) obj. 35520.7 iterations 2
# Cbc0038I Pass  25: suminf.    0.25669 (3) obj. 35520.7 iterations 0
# Cbc0038I Pass  26: suminf.    0.25669 (3) obj. 35520.7 iterations 0
# Cbc0038I Pass  27: suminf.    0.25669 (3) obj. 35520.7 iterations 0
# Cbc0038I Pass  28: suminf.    0.25669 (3) obj. 35520.7 iterations 0
# Cbc0038I Pass  29: suminf.    0.25669 (3) obj. 35520.7 iterations 0
# Cbc0038I Pass  30: suminf.    0.25669 (3) obj. 35520.7 iterations 0
# Cbc0038I Pass  31: suminf.    0.25669 (3) obj. 35520.7 iterations 0
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 2 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 4 rows 6 columns, reduced to 3 rows 4 columns
# Cbc0038I Mini branch and bound did not improve solution (0.00 seconds)
# Cbc0038I After 0.00 seconds - Feasibility pump exiting with objective of 35540 - took 0.00 seconds
# Cbc0012I Integer solution of 35540 found by feasibility pump after 0 iterations and 0 nodes (0.00 seconds)
# Cbc0001I Search completed - best objective 35540, took 0 iterations and 0 nodes (0.00 seconds)
# Cbc0035I Maximum depth 0, 1 variables fixed on reduced cost
# Cuts at root node changed objective from 35356 to 35540
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                35540.00000000
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.00
# Time (Wallclock seconds):       0.00
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.01
#
# Status: 1
# Objective Value (Profit): 35540.0
# x1 = 0.0
# x2 = 700.0
# x3 = 3500.0
# y1 = 0.0
# y2 = 1.0
# y3 = 1.0

# %% [markdown]
# # Q3

# %%
from pulp import LpMaximize, LpProblem, LpVariable

# Create a linear programming problem
prob = LpProblem(name="Maximize_Profit", sense=LpMaximize)

# Define decision variables
y1 = LpVariable(name="y1", cat="Binary")
y2 = LpVariable(name="y2", cat="Binary")
y3 = LpVariable(name="y3", cat="Binary")
y4 = LpVariable(name="y4", cat="Binary")

# Define the objective function
prob += 9 * y1 + 5 * y2 + 6 * y3 + 4* y4, "Profit"

# Add constraints
prob += 6 * y1 + 3 * y2 + 5 * y3 + 2 * y4 <= 10, "Constraint1"
prob += y3 + y4 <= 1, "Constraint2"
prob += y1 >= y3, "Constraint3"
prob += y2 >= y4, "Constraint4"

# Solve the problem
prob.solve()

# Print the results
print("Status:", prob.status)
print("Objective Value (Profit):", round(prob.objective.value(), 2))

# Print the values of decision variables
for var in prob.variables():
    print(f"{var.name} = {var.value()}")
# Out:
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/sathira/anaconda3/envs/bio/lib/python3.9/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/b45935a2f95842c4a0b0bc28b080e2d9-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /tmp/b45935a2f95842c4a0b0bc28b080e2d9-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 32 RHS
# At line 37 BOUNDS
# At line 42 ENDATA
# Problem MODEL has 4 rows, 4 columns and 10 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 16.5 - 0.00 seconds
# Cgl0003I 1 fixed, 0 tightened bounds, 1 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 1 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 1 strengthened rows, 0 substitutions
# Cgl0004I processed model has 0 rows, 0 columns (0 integer (0 of which binary)) and 0 elements
# Cbc3007W No integer variables - nothing to do
# Cuts at root node changed objective from -14 to -1.79769e+308
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                14.00000000
# Enumerated nodes:               0
# Total iterations:               1
# Time (CPU seconds):             0.00
# Time (Wallclock seconds):       0.00
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Status: 1
# Objective Value (Profit): 14.0
# y1 = 1.0
# y2 = 1.0
# y3 = 0.0
# y4 = 0.0

# %% [markdown]
# # Q4

# %%
from pulp import LpMaximize, LpProblem, LpVariable

# Define the coefficients for the Return function
R = [8,9.5,8.5,7.5,9.5,10,9,8,10,9]
# Define the cost vector for each Project
C = [5,6,5.5,7,8,6.5,7.5,5,8.5,8]
# Create a linear programming problem
prob = LpProblem(name="Maximize_Return", sense=LpMaximize)

# Define decision variables
y = [LpVariable(name=f"y{i}", cat="Binary") for i in range(1, 11)]

# Define the Return function
Return = sum([R_i * y_i for R_i, y_i in zip(R, y)])

# Define the objective function
prob += Return, "Objective"

# Add constraints
prob += sum([C_i * y_i for C_i, y_i in zip(C,y)]) <=60,"Constraint1"
prob += sum([y_i for y_i in y[:6]]) >= 2, "Constraint2"
prob += sum([y_i for y_i in y[6:]]) >= 2, "Constraint3"
prob += sum([y_i for y_i in y]) >= 5, "Constraint4"
prob += sum([y_i for y_i in y[:6]]) <= 5, "Constraint5"
prob += sum([y_i for y_i in y[6:]]) <= 3, "Constraint6"
prob += sum([y_i for y_i in y]) <= 9, "Constraint7"
prob += y[1] + y[4] <= 1, "Constraint8"
prob += y[8] + y[9] == 1, "Constraint9"
prob += y[2] == y[6], "Constraint10"
prob += y[2] + y[3] <= y[5] * 2, "Constraint11"
prob += y[3] <= y[5] + y[6], "Constraint12"
prob += 2 * y[2] <= y[3] + y[7], "Constraint13"
prob += y[5] <= y[9], "Constraint14"

print(prob)

# Solve the problem
prob.solve()

# Print the results
print("Status:", prob.status)
print("Objective Value (Return):", round(prob.objective.value(), 2))

# Print the values of decision variables
for var in prob.variables():
    print(f"{var.name} = {var.value()}")
# Out:
# Maximize_Return:
# MAXIMIZE
# 8*y1 + 9*y10 + 9.5*y2 + 8.5*y3 + 7.5*y4 + 9.5*y5 + 10*y6 + 9*y7 + 8*y8 + 10*y9 + 0.0
# SUBJECT TO
# Constraint1: 5 y1 + 8 y10 + 6 y2 + 5.5 y3 + 7 y4 + 8 y5 + 6.5 y6 + 7.5 y7
#  + 5 y8 + 8.5 y9 <= 60
#
# Constraint2: y1 + y2 + y3 + y4 + y5 + y6 >= 2
#
# Constraint3: y10 + y7 + y8 + y9 >= 2
#
# Constraint4: y1 + y10 + y2 + y3 + y4 + y5 + y6 + y7 + y8 + y9 >= 5
#
# Constraint5: y1 + y2 + y3 + y4 + y5 + y6 <= 5
#
# Constraint6: y10 + y7 + y8 + y9 <= 3
#
# Constraint7: y1 + y10 + y2 + y3 + y4 + y5 + y6 + y7 + y8 + y9 <= 9
#
# Constraint8: y2 + y5 <= 1
#
# Constraint9: y10 + y9 = 1
#
# Constraint10: y3 - y7 = 0
#
# Constraint11: y3 + y4 - 2 y6 <= 0
#
# Constraint12: y4 - y6 - y7 <= 0
#
# Constraint13: 2 y3 - y4 - y8 <= 0
#
# Constraint14: - y10 + y6 <= 0
#
# VARIABLES
# 0 <= y1 <= 1 Integer
# 0 <= y10 <= 1 Integer
# 0 <= y2 <= 1 Integer
# 0 <= y3 <= 1 Integer
# 0 <= y4 <= 1 Integer
# 0 <= y5 <= 1 Integer
# 0 <= y6 <= 1 Integer
# 0 <= y7 <= 1 Integer
# 0 <= y8 <= 1 Integer
# 0 <= y9 <= 1 Integer
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/sathira/anaconda3/envs/bio/lib/python3.9/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/c46f491b20664c71b70c97ac84162b8a-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /tmp/c46f491b20664c71b70c97ac84162b8a-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 19 COLUMNS
# At line 117 RHS
# At line 132 BOUNDS
# At line 143 ENDATA
# Problem MODEL has 14 rows, 10 columns and 67 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 69.5 - 0.00 seconds
# Cgl0003I 3 fixed, 0 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 1 strengthened rows, 0 substitutions
# Cgl0004I processed model has 3 rows, 4 columns (4 integer (4 of which binary)) and 10 elements
# Cutoff increment increased from 1e-05 to 0.4999
# Cbc0038I Initial state - 0 integers unsatisfied sum - 0
# Cbc0038I Solution found of -69.5
# Cbc0038I Before mini branch and bound, 4 integers at bound fixed and 0 continuous
# Cbc0038I Mini branch and bound did not improve solution (0.00 seconds)
# Cbc0038I After 0.00 seconds - Feasibility pump exiting with objective of -69.5 - took 0.00 seconds
# Cbc0012I Integer solution of -69.5 found by feasibility pump after 0 iterations and 0 nodes (0.00 seconds)
# Cbc0001I Search completed - best objective -69.5, took 0 iterations and 0 nodes (0.00 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Cuts at root node changed objective from -69.5 to -69.5
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                69.50000000
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.00
# Time (Wallclock seconds):       0.00
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Status: 1
# Objective Value (Return): 69.5
# y1 = 1.0
# y10 = 1.0
# y2 = 1.0
# y3 = 1.0
# y4 = 1.0
# y5 = 0.0
# y6 = 1.0
# y7 = 1.0
# y8 = 1.0
# y9 = 0.0

# %% [markdown]
# # Q5

# %%
from pulp import LpMinimize, LpProblem, LpVariable


# Define the cost vector for each tower
C = [2,3,2.5,5,4,1.5,3.5,6,4.5,5.5,6]
# Create a linear programming problem
prob = LpProblem("Construction_Cost_Minimization", LpMinimize)

# Define decision variables
y = [LpVariable(name=f"y{i}", cat="Binary") for i in range(1, 12)]

# Define the Return function
Return = sum([C_i * y_i for C_i, y_i in zip(C, y)])

# Define the objective function
prob += Return, "Objective"

# Add constraints
prob += y[0] + y[4]+ y[6]+ y[7]+ y[9] >= 1, "Constraint1"
prob += y[1] + y[2]+ y[3]+ y[10] >= 1, "Constraint2"
prob += y[0] + y[1]+ y[2]+ y[5] >= 1, "Constraint3"
prob += y[0] + y[7]+ y[9]+ y[10] >= 1, "Constraint4"
prob += y[2] + y[3]+ y[4]+ y[7] >= 1,"Constraint5"
prob += y[0] + y[1]+ y[7]+ y[9] >= 1, "Constraint6"

# Solve the problem
prob.solve()

# Print the results
print("Status:", prob.status)
print("Objective Value (Return):", round(prob.objective.value(), 2))

# Print the values of decision variables
for var in prob.variables():
    print(f"{var.name} = {var.value()}")
# Out:
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/sathira/anaconda3/envs/bio/lib/python3.9/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/5892f5b908584e1da51a208197f78ec5-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /tmp/5892f5b908584e1da51a208197f78ec5-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 70 RHS
# At line 77 BOUNDS
# At line 89 ENDATA
# Problem MODEL has 6 rows, 11 columns and 25 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 4.5 - 0.00 seconds
# Cgl0004I processed model has 6 rows, 10 columns (10 integer (10 of which binary)) and 25 elements
# Cutoff increment increased from 1e-05 to 0.4999
# Cbc0038I Initial state - 0 integers unsatisfied sum - 0
# Cbc0038I Solution found of 4.5
# Cbc0038I Before mini branch and bound, 10 integers at bound fixed and 0 continuous
# Cbc0038I Mini branch and bound did not improve solution (0.00 seconds)
# Cbc0038I After 0.00 seconds - Feasibility pump exiting with objective of 4.5 - took 0.00 seconds
# Cbc0012I Integer solution of 4.5 found by feasibility pump after 0 iterations and 0 nodes (0.00 seconds)
# Cbc0001I Search completed - best objective 4.5, took 0 iterations and 0 nodes (0.00 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Cuts at root node changed objective from 4.5 to 4.5
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                4.50000000
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.00
# Time (Wallclock seconds):       0.00
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Status: 1
# Objective Value (Return): 4.5
# y1 = 1.0
# y10 = 0.0
# y11 = 0.0
# y2 = 0.0
# y3 = 1.0
# y4 = 0.0
# y5 = 0.0
# y6 = 0.0
# y7 = 0.0
# y8 = 0.0
# y9 = 0.0

# %% [markdown]
# # Q11

# %%
from pulp import LpVariable, LpProblem, lpSum, LpMaximize

# Create a linear programming problem
prob = LpProblem("Profit_Maximization", LpMaximize)

# Define binary variables
y = {(i, j): LpVariable(name=f"y_{i}_{j}", cat='Binary') for i in range(1, 4) for j in range(1, 4)}

# Define the objective function
prob += lpSum([y[1, 1], 3 * y[1, 2], 3 * y[1, 3], 2 * y[2, 2], 3 * y[2, 3], -y[3, 1], 2 * y[3, 2], 4 * y[3, 3]])

# Define the constraints
prob += lpSum([y[1, 1], y[1, 2], y[1, 3]]) <= 1
prob += lpSum([y[2, 1], y[2, 2], y[2, 3]]) <= 1
prob += lpSum([y[3, 1], y[3, 2], y[3, 3]]) <= 1
prob += lpSum([y[1, 1], 2* y[1, 2], 3 * y[1, 3], y[2, 1], 2 * y[2, 2], 3 * y[2, 3], y[3, 1], 2 * y[3, 2], 3 * y[3, 3]]) == 5

# Solve the problem
prob.solve()

# Print the results
print("Objective Value (Profit):", prob.objective.value())
for var in prob.variables():
    print(f"{var.name}: {var.value()}")
# Out:
# Objective Value (Profit): 7.0
# y_1_1: 0.0
# y_1_2: 1.0
# y_1_3: 0.0
# y_2_1: 0.0
# y_2_2: 0.0
# y_2_3: 0.0
# y_3_1: 0.0
# y_3_2: 0.0
# y_3_3: 1.0

# %% [markdown]
# # Q12

# %%
from pulp import LpVariable, LpProblem, lpSum, LpMinimize, LpInteger

# Create a linear programming problem
prob = LpProblem("Waste_Minimization", LpMinimize)

# Define integer variables
x = [LpVariable(name=f"x_{i}", lowBound=0, cat=LpInteger) for i in range(1, 7)]

# Define the objective function
prob += 17*lpSum(x)-(25 * 3 + 20 * 5 + 15 * 9) 

# Define the constraints
prob += 5 * x[0] + 4 * x[1] + 2 * x[2] + 2 * x[3] + x[4] >= 25
prob += x[1] + 2 * x[2] + x[4] + 3 * x[5] >= 20
prob += x[3] + x[4] >= 15

# Solve the problem
prob.solve()

# Print the results
print("Objective Value (Waste):", prob.objective.value())
for var in prob.variables():
    print(f"{var.name}: {var.value()}")
# Out:
# Objective Value (Waste): 13.0
# x_1: 0.0
# x_2: 3.0
# x_3: 0.0
# x_4: 0.0
# x_5: 15.0
# x_6: 1.0

# %% [markdown]
# # Q12 Alternative Formulation

# %%
from pulp import LpVariable, LpProblem, lpSum, LpMinimize, LpInteger

# Create a linear programming problem
prob = LpProblem("Waste_Minimization", LpMinimize)

# Define integer variables
x = [LpVariable(name=f"x_{i}", lowBound=0, cat=LpInteger) for i in range(1, 7)]
w = [2,0,1,2,0,2]

# Define the objective function
prob +=  sum([w_i * x_i for w_i, x_i in zip(w,x)])

# Define the constraints
prob += 5 * x[0] + 4 * x[1] + 2 * x[2] + 2 * x[3] + x[4] == 25
prob += x[1] + 2 * x[2] + x[4] + 3 * x[5] == 20
prob += x[3] + x[4] == 15

# Solve the problem
prob.solve()

# Print the results
print("Objective Value (Waste):", prob.objective.value())
for var in prob.variables():
    print(f"{var.name}: {var.value()}")
# Out:
# Objective Value (Waste): 13.0
# x_1: 0.0
# x_2: 1.0
# x_3: 1.0
# x_4: 4.0
# x_5: 11.0
# x_6: 2.0

# %% [markdown]
# # Q7

# %%
from pulp import LpVariable, LpProblem, lpSum, LpMaximize, LpBinary

# Create a linear programming problem
prob = LpProblem("Profit_Maximization", LpMaximize)

# Define variables
x = [LpVariable(name=f"x_{i}", lowBound=0, cat=LpInteger) for i in range(1, 4)]
y = [LpVariable(name=f"y_{i}", cat=LpBinary) for i in range(1, 4)]
k = [LpVariable(name=f"k_{i}", cat=LpBinary) for i in range(1, 3)]

# Define M values (big-M)
M1 = 1000  # Adjust as needed
M2 = 1000  # Adjust as needed

# Define the objective function
prob += 5 * x[0] + 7 * x[1] + 3 * x[2]

# Define the constraints
prob += x[0] <= 7 * y[0]
prob += x[1] <= 5 * y[1]
prob += x[2] <= 9 * y[2]
prob += lpSum(y) <= 2
prob += 3 * x[0] + 4 * x[1] + 2 * x[2] <= 30 + M1 * k[0]
prob += 4 * x[0] + 6 * x[1] + 2 * x[2] <= 40 + M2 * k[1]
prob += lpSum(k) == 1

# Solve the problem
prob.solve()

# Print the results
print("Objective Value (Profit):", prob.objective.value())
for var in prob.variables():
    print(f"{var.name}: {var.value()}")
# Out:
# Objective Value (Profit): 54.0
# k_1: 1.0
# k_2: 0.0
# x_1: 6.0
# x_2: 0.0
# x_3: 8.0
# y_1: 1.0
# y_2: 0.0
# y_3: 1.0
